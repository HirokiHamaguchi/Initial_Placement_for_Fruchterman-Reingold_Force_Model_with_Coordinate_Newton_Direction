# %%
from src.python.getMatrix import getMatrixByName, getMatrixes
from src.python.visMat import visMat
from src.python.visGraph import visGraph
from src.python.spring_layout import spring_layout

import networkx as nx
import numpy as np
import scipy.sparse
import time

# %%
mat = getMatrixByName("jagmesh1")
print(mat.shape, mat.nnz, mat.dtype, np.min(mat.data), np.max(mat.data))
mat.data = np.abs(mat.data)

visMat(mat)

G = nx.Graph(mat)
t0 = time.perf_counter()
pos = spring_layout(G, method="FR_RS")
print(f"{time.perf_counter() - t0:.3f} [sec]")
visGraph(G, pos)
# Out:
# (936, 936) 6264 float64 1.0 1.0
# Using sparse solver
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[2], line 9
#       7 G = nx.Graph(mat)
#       8 t0 = time.perf_counter()
# ----> 9 pos = spring_layout(G, method="FR_RS")
#      10 print(f"{time.perf_counter() - t0:.3f} [sec]")
#      11 visGraph(G, pos)
#
# File c:\Users\MEIP-users\Documents\University\FruchtermanReingoldByRandomSubspace\.venv\Lib\site-packages\networkx\utils\decorators.py:789, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     788 def func(*args, __wrapper=None, **kwargs):
# --> 789     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 16:4, in argmap_spring_layout_13(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed, method)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~\Documents\University\FruchtermanReingoldByRandomSubspace\src\python\spring_layout.py:152, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed, method)
#     150         nnodes, _ = A.shape
#     151         k = dom_size / np.sqrt(nnodes)
# --> 152     pos = _sparse_fruchterman_reingold(
#     153         A, k, pos_arr, fixed, iterations, threshold, dim, seed, method
#     154     )
#     155 except ValueError:
#     156     print("Using dense solver")  # ! added
#
# File c:\Users\MEIP-users\Documents\University\FruchtermanReingoldByRandomSubspace\.venv\Lib\site-packages\networkx\utils\decorators.py:789, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     788 def func(*args, __wrapper=None, **kwargs):
# --> 789     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 24:4, in argmap__sparse_fruchterman_reingold_21(A, k, pos, fixed, iterations, threshold, dim, seed, method)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File ~\Documents\University\FruchtermanReingoldByRandomSubspace\src\python\_sparse_fr.py:132, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed, method)
#     130     return pos
#     131 elif method == "FR_RS":
# --> 132     raise NotImplementedError("FR_RS method is not implemented yet")
#     133 else:
#     134     raise ValueError("method is unknown")
#
# NotImplementedError: FR_RS method is not implemented yet
